# %%
# !pip install tensorflow==2.10.1
# Out:
# Collecting tensorflow==2.10.1
#   Downloading tensorflow-2.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.51.1)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (3.9.0)
# Collecting keras<2.11,>=2.10.0 (from tensorflow==2.10.1)
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.9 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.10.1)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (16.0.0)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (21.3)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.10.1)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 56.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (59.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.16.0)
# Collecting tensorboard<2.11,>=2.10 (from tensorflow==2.10.1)
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 48.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.31.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow==2.10.1)
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 36.0 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (4.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.10.1) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.20.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 55.7 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 53.4 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.3.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow==2.10.1) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (4.9)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.2.2)
# Installing collected packages: tensorboard-plugin-wit, keras, tensorflow-estimator, tensorboard-data-server, protobuf, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.6.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.6.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.6.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.6 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# cudf 23.6.1 requires protobuf<4.22,>=4.21.6, but you have protobuf 3.19.6 which is incompatible.
# cuml 23.6.0 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# dask-cudf 23.6.1 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-pubsub 2.17.1 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.51.1 which is incompatible.
# kfp 2.0.1 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# onnx 1.14.0 requires protobuf>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-datasets 4.9.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-decision-forests 1.4.0 requires tensorflow~=2.12.0, but you have tensorflow 2.10.1 which is incompatible.
# tensorflow-serving-api 2.12.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-serving-api 2.12.1 requires tensorflow<3,>=2.12.0, but you have tensorflow 2.10.1 which is incompatible.
# tensorflow-text 2.12.1 requires tensorflow<2.13,>=2.12.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.10.1 which is incompatible.
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.10.0 keras-preprocessing-1.1.2 protobuf-3.19.6 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.1 tensorflow-estimator-2.10.0

# %%
import os
import cv2
import re
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import matplotlib.image as mpimg
from glob import glob
from tqdm import tqdm
from tensorflow.keras.models import Model, load_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Input, UpSampling2D, AveragePooling2D, MaxPooling2D, LeakyReLU, concatenate, Add
from tensorflow.keras.layers import Flatten, Dense, MaxPool2D, ReLU, BatchNormalization, Concatenate, Lambda, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
# Out:
# 2023-08-08 17:20:46.302404: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
print(tf.__version__)
print(np.__version__)
print(cv2.__version__)
# Out:
# 2.10.1
# 1.23.5
# 4.8.0

# %%
#Global variable
BATCH_SIZE = 16
W,H = 256, 256
CHANNEL = 3
lr = 1e-6
epochs = 100

# %%
model_path = "ResUnet_for_skull_stripping.h5"
csv_path = "ResUnet_for_skull_stripping.csv"
path = "/kaggle/input/skull-stripping/temp"
split = 0.1

# %% [markdown]
# # Evaluation Metrics

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection  + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
#create folder for save augmented images
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %% [markdown]
# # Utility Function

# %%
#load dataset
def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "images/*")), key=lambda x: int(re.search(r'\d+', x).group()))
    masks = sorted(glob(os.path.join(path, "mask/*")), key=lambda x: int(re.search(r'\d+', x).group()))

    return images, masks

# %%
#process image function
def read_img(path):
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    img = cv2.resize(img, (256, 256))
    img = img / 255
    img = img.astype(np.float32)
    return img

#process mask function
def read_mask(path):
    mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (256, 256))
    mask = mask / 255
    mask = np.expand_dims(mask, axis=-1)
    mask = mask.astype(np.float32)
    return mask

# %%
#enable to apply cv
def preprocess(x, y):
    def f(x, y):
        x = x.decode()
        y = y.decode()

        x = read_img(x)
        y = read_mask(y)
        return x, y

    image, mask = tf.numpy_function(f, [x, y], [tf.float32, tf.float32])
    image.set_shape([256, 256, 3])
    mask.set_shape([256, 256, 1])

    return image, mask

# %%
def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.shuffle(buffer_size=1000)
    dataset = dataset.map(preprocess)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(2)
    return dataset

# %% [markdown]
# # Model | ResUNet

# %%
def batch_norm_relu(inputs):
    x = BatchNormalization()(inputs)
    x = Activation("relu")(x)
    return x

# %%
def residual_block(inputs, num_filters, strides=1):
    x = batch_norm_relu(inputs)
    x = Conv2D(num_filters, (3,3), padding='same', strides=strides)(x)
    x = batch_norm_relu(x)
    x = Conv2D(num_filters, (3,3), padding='same', strides=1)(x)
    
    short = Conv2D(num_filters, 1, padding='same', strides=strides)(inputs)
    x = Add()([x, short])
    return x

# %%
def decoder_block(inputs, skip, filters):
    x = UpSampling2D((2,2))(inputs)
    x = Concatenate()([x, skip])
    x = residual_block(x, filters, strides=1)
    return x

# %%
def build_model(input_shape):
    inputs = Input(input_shape)
    
    #encoder
    x = Conv2D(64, (3,3), padding='same', strides=1)(inputs)
    x = batch_norm_relu(x)
    x = Conv2D(64, (3,3), padding='same', strides=1)(inputs)
    
    s = Conv2D(64, 1, padding='same')(inputs)
    e1 = Concatenate()([x,s])
    
    e2 = residual_block(e1, 128, strides=2)
    e3 = residual_block(e2, 256, strides=2)
    e4 = residual_block(e3, 512, strides=2)
    
    bn = residual_block(e4, 1024, strides=2)
    
    #Decoder
    d1 = decoder_block(bn, e4, 512)
    d2 = decoder_block(d1, e3, 256)
    d3 = decoder_block(d2, e2, 128)
    d4 = decoder_block(d3, e1, 64)
    
    outputs = Conv2D(1, 1, padding='same', activation='sigmoid')(d4)
    
    model = Model(inputs, outputs, name="ResUNet")
    
    return model

# %%
shape = (256, 256, 3)
model = build_model(shape)
model.summary()
# Out:
# Model: "ResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 64  256         ['input_1[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 256, 256, 12  0           ['conv2d_1[0][0]',
#                                 8)                                'conv2d_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 12  512        ['concatenate[0][0]']
#  rmalization)                   8)
#
#  activation_1 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_1[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_1[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  16512       ['concatenate[0][0]']
#                                 8)
#
#  add (Add)                      (None, 128, 128, 12  0           ['conv2d_4[0][0]',
#                                 8)                                'conv2d_5[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['add[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 256)  295168      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 256)  33024       ['add[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 256)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['add_1[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 512)  1180160     ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  131584      ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 512)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['add_2[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 1024  4719616     ['activation_7[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_12[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 1024  525312      ['add_2[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 16, 16, 1024  0           ['conv2d_13[0][0]',
#                                 )                                 'conv2d_14[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 1024  0           ['add_3[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 1536  0           ['up_sampling2d[0][0]',
#                                 )                                 'add_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1536  6144       ['concatenate_1[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1536  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 512)  7078400     ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_10[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 512)  786944      ['concatenate_1[0][0]']
#
#  add_4 (Add)                    (None, 32, 32, 512)  0           ['conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0          ['add_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 768)  0           ['up_sampling2d_1[0][0]',
#                                                                   'add_1[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 768)  3072       ['concatenate_2[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 768)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 256)  1769728     ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_12[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 256)  196864      ['concatenate_2[0][0]']
#
#  add_5 (Add)                    (None, 64, 64, 256)  0           ['conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 25  0          ['add_5[0][0]']
#                                 6)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_2[0][0]',
#                                 4)                                'add[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 38  1536       ['concatenate_3[0][0]']
#  ormalization)                  4)
#
#  activation_13 (Activation)     (None, 128, 128, 38  0           ['batch_normalization_13[0][0]']
#                                 4)
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 12  442496      ['activation_13[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 12  512        ['conv2d_21[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  49280       ['concatenate_3[0][0]']
#                                 8)
#
#  add_6 (Add)                    (None, 128, 128, 12  0           ['conv2d_22[0][0]',
#                                 8)                                'conv2d_23[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 12  0          ['add_6[0][0]']
#                                 8)
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 25  0           ['up_sampling2d_3[0][0]',
#                                 6)                                'concatenate[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 25  1024       ['concatenate_4[0][0]']
#  ormalization)                  6)
#
#  activation_15 (Activation)     (None, 256, 256, 25  0           ['batch_normalization_15[0][0]']
#                                 6)
#
#  conv2d_24 (Conv2D)             (None, 256, 256, 64  147520      ['activation_15[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 64  256        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 256, 256, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 256, 256, 64  16448       ['concatenate_4[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 256, 256, 64  0           ['conv2d_25[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 256, 256, 1)  65          ['add_7[0][0]']
#
# ==================================================================================================
# Total params: 33,236,225
# Trainable params: 33,222,529
# Non-trainable params: 13,696
# __________________________________________________________________________________________________

# %%
metrics = [dice_coef, iou, Recall(), Precision()]
model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)

# %% [markdown]
# # Data Preprocessing

# %%
images, masks = load_data(path)
print(f'image: {len(images)} - Masks: {len(masks)}')
# Out:
# image: 722 - Masks: 722

# %%
train_image = images
train_masks = masks
test_image = images[700:]
test_masks = masks[700:]
print(f'image: {len(train_image)} - Masks: {len(train_masks)}')
print(f'image: {len(test_image)} - Masks: {len(test_masks)}')
# Out:
# image: 722 - Masks: 722
# image: 22 - Masks: 22

# %%
n = 200
img = cv2.imread(train_image[n], cv2.IMREAD_COLOR)
msk = cv2.imread(train_masks[n], cv2.IMREAD_COLOR)

fig, ax = plt.subplots(1,2, figsize=(10,8))
ax[0].imshow(img)
ax[1].imshow(msk)

# %%
#convert dataset into tf dataset
train_dataset = tf_dataset(train_image, train_masks, batch=BATCH_SIZE)
test_dataset = tf_dataset(test_image, test_masks, batch=BATCH_SIZE)

# %%
#Callbacks
Callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True), 
    CSVLogger(csv_path),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
    EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
]

# %%
#training
model.fit(
    train_dataset,
    epochs=60,
    validation_data=test_dataset, 
    callbacks=Callbacks
    )
# Out:
# Epoch 1/60
# 46/46 [==============================] - ETA: 0s - loss: 0.3903 - dice_coef: 0.6113 - iou: 0.4487 - recall: 0.8406 - precision: 0.5382
# Epoch 1: val_loss improved from inf to 0.64310, saving model to ResUnet_for_skull_stripping.h5
# 46/46 [==============================] - 48s 733ms/step - loss: 0.3903 - dice_coef: 0.6113 - iou: 0.4487 - recall: 0.8406 - precision: 0.5382 - val_loss: 0.6431 - val_dice_coef: 0.3549 - val_iou: 0.2158 - val_recall: 0.9969 - val_precision: 0.4747 - lr: 1.0000e-06
# Epoch 2/60
# 46/46 [==============================] - ETA: 0s - loss: 0.2437 - dice_coef: 0.7578 - iou: 0.6109 - recall: 0.8603 - precision: 0.7041
# Epoch 2: val_loss improved from 0.64310 to 0.61361, saving model to ResUnet_for_skull_stripping.h5
# 46/46 [==============================] - 31s 662ms/step - loss: 0.2437 - dice_coef: 0.7578 - iou: 0.6109 - recall: 0.8603 - precision: 0.7041 - val_loss: 0.6136 - val_dice_coef: 0.3816 - val_iou: 0.2358 - val_recall: 0.9369 - val_precision: 0.5922 - lr: 1.0000e-06
# Epoch 3/60
# 46/46 [==============================] - ETA: 0s - loss: 0.1967 - dice_coef: 0.8038 - iou: 0.6724 - recall: 0.8616 - precision: 0.7826
# Epoch 3: val_loss improved from 0.61361 to 0.57505, saving model to ResUnet_for_skull_stripping.h5
# 46/46 [==============================] - 30s 660ms/step - loss: 0.1967 - dice_coef: 0.8038 - iou: 0.6724 - recall: 0.8616 - precision: 0.7826 - val_loss: 0.5751 - val_dice_coef: 0.4249 - val_iou: 0.2698 - val_recall: 0.8600 - val_precision: 0.6744 - lr: 1.0000e-06
# Epoch 4/60
# 46/46 [==============================] - ETA: 0s - loss: 0.1625 - dice_coef: 0.8388 - iou: 0.7227 - recall: 0.8650 - precision: 0.8456
# Epoch 4: val_loss improved from 0.57505 to 0.50533, saving model to ResUnet_for_skull_stripping.h5
60
# 46/46 [==============================] - ETA: 0s - loss: 0.0476 - dice_coef: 0.9522 - iou: 0.9089 - recall: 0.9471 - precision: 0.9632
# Epoch 41: val_loss did not improve from 0.06396
# 46/46 [==============================] - 29s 631ms/step - loss: 0.0476 - dice_coef: 0.9522 - iou: 0.9089 - recall: 0.9471 - precision: 0.9632 - val_loss: 0.0650 - val_dice_coef: 0.9346 - val_iou: 0.8773 - val_recall: 0.8943 - val_precision: 0.9789 - lr: 1.0000e-06
# Epoch 42/60
# 46/46 [==============================] - ETA: 0s - loss: 0.0467 - dice_coef: 0.9532 - iou: 0.9107 - recall: 0.9480 - precision: 0.9638
# Epoch 42: val_loss did not improve from 0.06396
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-07.
# 46/46 [==============================] - 29s 635ms/step - loss: 0.0467 - dice_coef: 0.9532 - iou: 0.9107 - recall: 0.9480 - precision: 0.9638 - val_loss: 0.0698 - val_dice_coef: 0.9333 - val_iou: 0.8750 - val_recall: 0.8790 - val_precision: 0.9839 - lr: 1.0000e-06
# Epoch 43/60
# 46/46 [==============================] - ETA: 0s - loss: 0.0466 - dice_coef: 0.9531 - iou: 0.9104 - recall: 0.9463 - precision: 0.9653
# Epoch 43: val_loss did not improve from 0.06396
# 46/46 [==============================] - 29s 638ms/step - loss: 0.0466 - dice_coef: 0.9531 - iou: 0.9104 - recall: 0.9463 - precision: 0.9653 - val_loss: 0.0645 - val_dice_coef: 0.9349 - val_iou: 0.8777 - val_recall: 0.8937 - val_precision: 0.9803 - lr: 1.0000e-07

# %% [markdown]
# # Prediction & Visualization

# %%
path = "/kaggle/working/predicted"
create_dir(path)

# %%
for img, msk in tqdm(zip(test_image, test_masks), total=len(test_image)):
    image_name = img.split("/")[-1]

    ori_x = cv2.imread(img, cv2.IMREAD_COLOR)
    ori_x = cv2.resize(ori_x, (W,H))
    x = ori_x / 255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)

    ori_y = cv2.imread(msk, cv2.IMREAD_GRAYSCALE)
    ori_y = cv2.resize(ori_y, (W,H))
    ori_y = np.expand_dims(ori_y, axis=-1)

    y_pred = model.predict(x)[0] > 0.5  
    y_pred = y_pred.astype(np.int32)
    y_pred = y_pred.reshape(256, 256, 1)

    print(ori_x.shape, ori_y.shape, y_pred.shape)
    save_image_path = f"/kaggle/working/predicted/{image_name}"

    sep_line = np.ones((H, 10, 3)) * 255
    cat_image = np.concatenate([ori_y, y_pred*255], axis=1)
    cv2.imwrite(save_image_path, cat_image)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 897ms/step
#   5%|▍         | 1/22 [00:00<00:20,  1.04it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 22ms/step
#   9%|▉         | 2/22 [00:01<00:09,  2.15it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 21ms/step
#  18%|█▊        | 4/22 [00:01<00:03,  4.56it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 23ms/step
#  27%|██▋       | 6/22 [00:01<00:02,  6.63it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 22ms/step
#  36%|███▋      | 8/22 [00:01<00:01,  8.34it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 21ms/step
#  45%|████▌     | 10/22 [00:01<00:01,  9.06it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 22ms/step
#  55%|█████▍    | 12/22 [00:01<00:00, 10.24it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 25ms/step
#  64%|██████▎   | 14/22 [00:02<00:00, 11.08it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 22ms/step
#  73%|███████▎  | 16/22 [00:02<00:00, 11.58it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 22ms/step
#  82%|████████▏ | 18/22 [00:02<00:00, 12.00it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 22ms/step
#  91%|█████████ | 20/22 [00:02<00:00, 12.46it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 23ms/step
# 100%|██████████| 22/22 [00:02<00:00,  8.42it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)

# %%
i = "/kaggle/working/predicted/709.png"
i = cv2.imread(i, cv2.IMREAD_GRAYSCALE)
plt.imshow(i)
plt.xlabel("truth                                     predicted")
# Out:
# Text(0.5, 0, 'truth                                     predicted')

# %%
t_path = "/kaggle/working/"
image_folder = sorted(glob(os.path.join(t_path, "predicted/*")))

# %%
rows = 2
columns = 5

# Create a figure and axis objects
fig, axes = plt.subplots(rows, columns, figsize=(20, 5))

# Flatten the axes array to iterate through it easily
axes = axes.flatten()

# Loop through the images and display them
for i, ax in enumerate(axes):
    # Check if there are more images than needed for the grid
    if i < len(image_folder):
        # Read the image file
        image = mpimg.imread(image_folder[i])
        # Display the image
        ax.imshow(image)
        ax.axis("off")
    else:
        # If there are no more images, hide the remaining axes
        ax.axis("off")

# Adjust the spacing between the subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Stripping the Skull

# %%
test_img_path = train_image[102]
test_img_mask = train_masks[102]
test_img = read_img(test_img_path)
test_msk = read_mask(test_img_mask)
plt.imshow(test_img)

# %%
img = test_img.reshape(1, 256, 256, 3)
img.shape
# Out:
# (1, 256, 256, 3)

# %%
pred = model.predict(img)[0] > 0.5  
pred = pred.astype(np.int32)
pred_img = pred.reshape(256, 256, 1)
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
fig, ax = plt.subplots(1, 3, figsize=(16,8))
ax[0].imshow(test_img)
ax[0].set_xlabel("BRAIN")
ax[1].imshow(test_msk)
ax[1].set_xlabel("TRUE MASK")
ax[2].imshow(pred_img)
ax[2].set_xlabel("PREDICTED MASK")
# Out:
# Text(0.5, 0, 'PREDICTED MASK')

# %%
#save the predicted mask image
cv2.imwrite("/kaggle/working/mask-1.png", pred_img)
# Out:
# True

# %%
#read mask again
maskImg = cv2.imread("/kaggle/working/mask-1.png")
print(maskImg.shape)
maskImg = cv2.cvtColor(maskImg, cv2.COLOR_BGR2GRAY)
maskImg.shape
# Out:
# (256, 256, 3)
# (256, 256)

# %%
# Bitwise AND the masked brain image with the masked image to remove the skull
masked = cv2.bitwise_and(test_img, test_img, mask=maskImg)

# %%
#visualize
fig, ax = plt.subplots(1, 3, figsize=(15, 12))
ax[0].imshow(test_img)
ax[0].set_xlabel("MRI BRAIN")
ax[1].imshow(maskImg)
ax[1].set_xlabel("BRAIN MASK")
ax[2].imshow(masked)
ax[2].set_xlabel("SKULL STRIPPED BRAIN")
# Out:
# Text(0.5, 0, 'SKULL STRIPPED BRAIN')
