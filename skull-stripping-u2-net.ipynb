# %%
# !pip install tensorflow==2.10.1
# Out:
# Collecting tensorflow==2.10.1
#   Downloading tensorflow-2.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.51.1)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (3.9.0)
# Collecting keras<2.11,>=2.10.0 (from tensorflow==2.10.1)
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 73.6 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.10.1)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (16.0.0)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (21.3)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.10.1)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (59.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.16.0)
# Collecting tensorboard<2.11,>=2.10 (from tensorflow==2.10.1)
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 83.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.31.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow==2.10.1)
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (4.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.10.1) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.20.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 58.4 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 51.7 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.3.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow==2.10.1) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (4.9)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.2.2)
# Installing collected packages: tensorboard-plugin-wit, keras, tensorflow-estimator, tensorboard-data-server, protobuf, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.6.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.6.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.6.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.6 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# cudf 23.6.1 requires protobuf<4.22,>=4.21.6, but you have protobuf 3.19.6 which is incompatible.
# cuml 23.6.0 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# dask-cudf 23.6.1 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-pubsub 2.17.1 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.51.1 which is incompatible.
# kfp 2.0.1 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# onnx 1.14.0 requires protobuf>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-datasets 4.9.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-decision-forests 1.4.0 requires tensorflow~=2.12.0, but you have tensorflow 2.10.1 which is incompatible.
# tensorflow-serving-api 2.12.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-serving-api 2.12.1 requires tensorflow<3,>=2.12.0, but you have tensorflow 2.10.1 which is incompatible.
# tensorflow-text 2.12.1 requires tensorflow<2.13,>=2.12.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.10.1 which is incompatible.
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.10.0 keras-preprocessing-1.1.2 protobuf-3.19.6 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.1 tensorflow-estimator-2.10.0

# %%
import os
import cv2
import re
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import matplotlib.image as mpimg
from glob import glob
from tqdm import tqdm
from tensorflow.keras.models import Model, load_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Input, UpSampling2D, AveragePooling2D, MaxPooling2D, LeakyReLU, concatenate
from tensorflow.keras.layers import Flatten, Dense, MaxPool2D, ReLU, BatchNormalization, Concatenate, Lambda, Activation, Dropout, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
# Out:
# 2023-08-10 19:00:25.809958: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
print(tf.__version__)
print(np.__version__)
print(cv2.__version__)
# Out:
# 2.10.1
# 1.23.5
# 4.8.0

# %%
#Global variable
BATCH_SIZE = 16
W,H = 256, 256
CHANNEL = 3
lr = 1e-5
epochs = 50

# %%
model_path = "u2net_for_skull_stripping.h5"
csv_path = "u2net_for_skull_stripping.csv"
path = "/kaggle/input/skull-stripping/temp"
split = 0.1

# %% [markdown]
# # Evaluation Metrics

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection  + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# # Utility Function for Data Processing

# %%
#load dataset
def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "images/*")), key=lambda x: int(re.search(r'\d+', x).group()))
    masks = sorted(glob(os.path.join(path, "mask/*")), key=lambda x: int(re.search(r'\d+', x).group()))

    return images, masks

# %%
#create folder for save augmented images
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
#process image function
def read_img(path):
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    img = cv2.resize(img, (256, 256))
    img = img / 255
    img = img.astype(np.float32)
    return img

#process mask function
def read_mask(path):
    mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (256, 256))
    mask = mask / 255
    mask = np.expand_dims(mask, axis=-1)
    mask = mask.astype(np.float32)
    return mask

# %%
#enable to apply cv
def preprocess(x, y):
    def f(x, y):
        x = x.decode()
        y = y.decode()

        x = read_img(x)
        y = read_mask(y)
        return x, y

    image, mask = tf.numpy_function(f, [x, y], [tf.float32, tf.float32])
    image.set_shape([256, 256, 3])
    mask.set_shape([256, 256, 1])

    return image, mask

# %%
def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.shuffle(buffer_size=1000)
    dataset = dataset.map(preprocess)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(2)
    return dataset

# %% [markdown]
# # Model | U2Net

# %%
def conv_block(inputs, out_ch, rate=1):
    x = Conv2D(out_ch, 3, padding='same', dilation_rate=1)(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def RSU_L(inputs, out_ch, int_ch, num_layers, rate=2):
    #initial convolution 
    x = conv_block(inputs, out_ch)
    init_feature = x
    
    #Encoder    
    skip_connection = []
    x = conv_block(x, int_ch)
    skip_connection.append(x)
    
    for i in range(num_layers-2):
        x = MaxPool2D((2,2))(x)
        x = conv_block(x, int_ch)
        skip_connection.append(x)
    
    #bridge
    b = conv_block(x, int_ch, rate=rate)
        
    #Decoder
    skip_connection.reverse()
    
    x = Concatenate()([b, skip_connection[0]])
    x = conv_block(x, int_ch)
    
    for i in range(num_layers-3):
        x = UpSampling2D((2,2), interpolation='bilinear')(x)
        x = Concatenate()([x, skip_connection[i+1]])
        x = conv_block(x, int_ch)
        
    x = UpSampling2D((2,2), interpolation='bilinear')(x)
    x = Concatenate()([x, skip_connection[-1]])
    x = conv_block(x, out_ch)
    
    #Add
    x = Add()([x, init_feature])
    return x

# %%
#Dilated Residual U-Block
def RSU_4F(inputs, out_ch, int_ch):
    x0 = conv_block(inputs, out_ch, rate=1)
    
    #encoder
    x1 = conv_block(x0, int_ch, rate=1)
    x2 = conv_block(x1, int_ch, rate=2)
    x3 = conv_block(x2, int_ch, rate=4)
    
    x4 = conv_block(x3, int_ch, rate=8)
    
    #Decoder
    x = Concatenate()([x4, x3])
    x = conv_block(x, int_ch, rate=4)
    
    x = Concatenate()([x, x2])
    x = conv_block(x, int_ch, rate=2)
    
    x = Concatenate()([x, x1])
    x = conv_block(x, out_ch, rate=1)
    
    x = Add()([x, x0])
    return x

# %%
def u2net(input_shape, out_ch, int_ch, num_classes=1):
    inputs = Input(input_shape)
    s0 = inputs
    
    #Encoder
    s1 = RSU_L(s0, out_ch[0], int_ch[0], 7)
    p1 = MaxPool2D((2,2))(s1)
    
    s2 = RSU_L(p1, out_ch[1], int_ch[1], 6)
    p2 = MaxPool2D((2,2))(s2)
    
    s3 = RSU_L(p2, out_ch[2], int_ch[2], 5)
    p3 = MaxPool2D((2,2))(s3)
    
    s4 = RSU_L(p3, out_ch[3], int_ch[3], 4)
    p4 = MaxPool2D((2,2))(s4)
    
    s5 = RSU_4F(p4, out_ch[4], int_ch[4])
    p5 = MaxPool2D((2,2))(s5)
    
    #Bridge
    b1 = RSU_4F(p5, out_ch[5], int_ch[5])
    b2 = UpSampling2D((2,2), interpolation='bilinear')(b1)
    
    #Decoder
    d1 = Concatenate()([b2, s5])
    d1 = RSU_4F(d1, out_ch[6], int_ch[6])
    u1 = UpSampling2D((2,2), interpolation='bilinear')(d1)
    
    d2 = Concatenate()([u1, s4])
    d2 = RSU_L(d2, out_ch[7], int_ch[7], 4)
    u2 = UpSampling2D((2,2), interpolation='bilinear')(d2)
    
    d3 = Concatenate()([u2, s3])
    d3 = RSU_L(d3, out_ch[8], int_ch[8], 5)
    u3 = UpSampling2D((2,2), interpolation='bilinear')(d3)
    
    d4 = Concatenate()([u3, s2])
    d4 = RSU_L(d4, out_ch[9], int_ch[9], 6)
    u4 = UpSampling2D((2,2), interpolation='bilinear')(d4)
    
    d5 = Concatenate()([u4, s1])
    d5 = RSU_L(d5, out_ch[10], int_ch[10], 7)
    
    #Side Outputs
    y1 = Conv2D(num_classes, 3, padding='same')(d5)
    
    y2 = Conv2D(num_classes, 3, padding='same')(d4)
    y2 = UpSampling2D((2,2), interpolation='bilinear')(y2)
    
    y3 = Conv2D(num_classes, 3, padding='same')(d3)
    y3 = UpSampling2D((4,4), interpolation='bilinear')(y3)
    
    y4 = Conv2D(num_classes, 3, padding='same')(d2)
    y4 = UpSampling2D((8,8), interpolation='bilinear')(y4)
    
    y5 = Conv2D(num_classes, 3, padding='same')(d1)
    y5 = UpSampling2D((16,16), interpolation='bilinear')(y5)
    
    y6 = Conv2D(num_classes, 3, padding='same')(b1)
    y6 = UpSampling2D((32,32), interpolation='bilinear')(y6)
    
    y0 = Concatenate()([y1, y2, y3, y4, y5, y6])
    y0 = Conv2D(num_classes, 3, padding='same')(y0)
    
    y0 = Activation("sigmoid")(y0)
    y1 = Activation("sigmoid")(y1)
    y2 = Activation("sigmoid")(y2)
    y3 = Activation("sigmoid")(y3)
    y4 = Activation("sigmoid")(y4)
    y5 = Activation("sigmoid")(y5)
    y6 = Activation("sigmoid")(y6)
    
    model = Model(inputs, outputs=[y0,y1,y2,y3,y4,y5,y6])
    return model

# %%
def build_u2net(input_shape, num_classes=1):
    out_ch = [64, 128, 256, 512, 512, 512, 512, 256, 128, 64, 64]
    int_ch = [32, 32, 64, 128, 256, 256, 256, 128, 64, 32, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

# %%
def build_u2net_lite(input_shape, num_classes=1):
    out_ch = [64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64]
    int_ch = [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

# %%
model = build_u2net((256, 256, 3))

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  18464       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  9248        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 32)   9248        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 32)   9248        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 16, 16, 32)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 32)    0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 32)     9248        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 32)    128         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 8, 8, 32)     0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 32)     9248        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 32)    128         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 8, 8, 32)     0           ['batch_normalization_7[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 64)     0           ['activation_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 32)     18464       ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 32)    128         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 32)     0           ['batch_normalization_8[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 32)   0           ['activation_8[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 64)   0           ['up_sampling2d[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 32)   18464       ['concatenate_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 32)  128         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 16, 16, 32)   0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 32)  0           ['activation_9[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 64)   0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 32)   18464       ['concatenate_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 32)  128         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_10[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 32)  0           ['activation_10[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64)   0           ['up_sampling2d_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 32)  128         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 32  0          ['activation_11[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 64  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 32  128        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 32  0          ['activation_12[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 64  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 64  36928       ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 256, 64  0           ['activation_13[0][0]',
#                                 )                                 'activation[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 64  0          ['add[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  73856       ['max_pooling2d_5[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  36896       ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 32)  0           ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 32)   9248        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 32)  128         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_16[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 32)   9248        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 32)  128         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_17[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 32)   9248        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 32)  128         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_18[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 8, 8, 32)    0           ['activation_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 8, 32)     9248        ['max_pooling2d_9[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 32)    128         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 8, 8, 32)     0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 8, 8, 32)     9248        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 32)    128         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 8, 8, 32)     0           ['batch_normalization_20[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 8, 8, 64)     0           ['activation_20[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 32)     18464       ['concatenate_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 32)    128         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 8, 8, 32)     0           ['batch_normalization_21[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 16, 16, 32)  0           ['activation_21[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 16, 16, 64)   0           ['up_sampling2d_5[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 32)   18464       ['concatenate_7[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_22[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 32)  0           ['activation_22[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 32, 32, 64)   0           ['up_sampling2d_6[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 32)   18464       ['concatenate_8[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_23[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 32)  0           ['activation_23[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 64)   0           ['up_sampling2d_7[0][0]',
#                                                                   'activation_16[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_9[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 32)  128         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_24[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 32  0          ['activation_24[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 64  0           ['up_sampling2d_8[0][0]',
#                                 )                                 'activation_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 12  73856       ['concatenate_10[0][0]']
#                                 8)
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 12  512        ['conv2d_25[0][0]']
#  ormalization)                  8)
#
#  activation_25 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_25[0][0]']
#                                 8)
#
#  add_1 (Add)                    (None, 128, 128, 12  0           ['activation_25[0][0]',
#                                 8)                                'activation_14[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 64, 64, 128)  0          ['add_1[0][0]']
#  )
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 256)  295168      ['max_pooling2d_10[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 64)   147520      ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_27[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 32, 32, 64)  0           ['activation_27[0][0]']
#  )
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 64)   36928       ['max_pooling2d_11[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_28[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 16, 16, 64)  0           ['activation_28[0][0]']
#  )
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 64)   36928       ['max_pooling2d_12[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 8, 8, 64)    0           ['activation_29[0][0]']
#  )
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 64)     36928       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 64)    256         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 64)    256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_31[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 8, 8, 128)    0           ['activation_31[0][0]',
#                                                                   'activation_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 64)     73792       ['concatenate_11[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 64)    256         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_32[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 16, 16, 64)  0           ['activation_32[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 16, 16, 128)  0           ['up_sampling2d_9[0][0]',
#                                                                   'activation_29[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 64)   73792       ['concatenate_12[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_33[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 32, 32, 64)  0           ['activation_33[0][0]']
#  )
#
#  concatenate_13 (Concatenate)   (None, 32, 32, 128)  0           ['up_sampling2d_10[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_13[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_34[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 64, 64, 64)  0           ['activation_34[0][0]']
#  )
#
#  concatenate_14 (Concatenate)   (None, 64, 64, 128)  0           ['up_sampling2d_11[0][0]',
#                                                                   'activation_27[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 256)  295168      ['concatenate_14[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_35[0][0]']
#
#  add_2 (Add)                    (None, 64, 64, 256)  0           ['activation_35[0][0]',
#                                                                   'activation_26[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 32, 32, 256)  0          ['add_2[0][0]']
#  )
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 512)  1180160     ['max_pooling2d_14[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 128)  589952      ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 128)  512        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_37[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 16, 16, 128)  0          ['activation_37[0][0]']
#  )
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 128)  147584      ['max_pooling2d_15[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 128)  512        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_38[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 8, 8, 128)   0           ['activation_38[0][0]']
#  )
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 128)    147584      ['max_pooling2d_16[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 128)   512         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 128)   512         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_40[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 8, 8, 256)    0           ['activation_40[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 128)    295040      ['concatenate_15[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 128)   512         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_41[0][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 16, 16, 128)  0          ['activation_41[0][0]']
#  )
#
#  concatenate_16 (Concatenate)   (None, 16, 16, 256)  0           ['up_sampling2d_12[0][0]',
#                                                                   'activation_38[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate_16[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 128)  512        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_42[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 32, 32, 128)  0          ['activation_42[0][0]']
#  )
#
#  concatenate_17 (Concatenate)   (None, 32, 32, 256)  0           ['up_sampling2d_13[0][0]',
#                                                                   'activation_37[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 512)  1180160     ['concatenate_17[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_43[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 512)  0           ['activation_43[0][0]',
#                                                                   'activation_36[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 16, 16, 512)  0          ['add_3[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 512)  2359808     ['max_pooling2d_17[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_44[0][0]']
#
# ...
#  )
#
#  conv2d_103 (Conv2D)            (None, 16, 16, 16)   2320        ['max_pooling2d_31[0][0]']
#
#  batch_normalization_103 (Batch  (None, 16, 16, 16)  64          ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 16, 16, 16)   0           ['batch_normalization_103[0][0]']
#
#  max_pooling2d_32 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_103[0][0]']
#  )
#
#  conv2d_104 (Conv2D)            (None, 8, 8, 16)     2320        ['max_pooling2d_32[0][0]']
#
#  batch_normalization_104 (Batch  (None, 8, 8, 16)    64          ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 8, 8, 16)     0           ['batch_normalization_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 8, 8, 16)     2320        ['activation_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 8, 8, 16)    64          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 8, 8, 16)     0           ['batch_normalization_105[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 8, 8, 32)     0           ['activation_105[0][0]',
#                                                                   'activation_104[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 8, 8, 16)     4624        ['concatenate_44[0][0]']
#
#  batch_normalization_106 (Batch  (None, 8, 8, 16)    64          ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 8, 8, 16)     0           ['batch_normalization_106[0][0]']
#
#  up_sampling2d_28 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_106[0][0]']
#  )
#
#  concatenate_45 (Concatenate)   (None, 16, 16, 32)   0           ['up_sampling2d_28[0][0]',
#                                                                   'activation_103[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 16, 16, 16)   4624        ['concatenate_45[0][0]']
#
#  batch_normalization_107 (Batch  (None, 16, 16, 16)  64          ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 16, 16, 16)   0           ['batch_normalization_107[0][0]']
#
#  up_sampling2d_29 (UpSampling2D  (None, 32, 32, 16)  0           ['activation_107[0][0]']
#  )
#
#  concatenate_46 (Concatenate)   (None, 32, 32, 32)   0           ['up_sampling2d_29[0][0]',
#                                                                   'activation_102[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 32, 32, 16)   4624        ['concatenate_46[0][0]']
#
#  batch_normalization_108 (Batch  (None, 32, 32, 16)  64          ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_108[0][0]']
#
#  up_sampling2d_30 (UpSampling2D  (None, 64, 64, 16)  0           ['activation_108[0][0]']
#  )
#
#  concatenate_47 (Concatenate)   (None, 64, 64, 32)   0           ['up_sampling2d_30[0][0]',
#                                                                   'activation_101[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 64, 64, 16)   4624        ['concatenate_47[0][0]']
#
#  batch_normalization_109 (Batch  (None, 64, 64, 16)  64          ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_109[0][0]']
#
#  up_sampling2d_31 (UpSampling2D  (None, 128, 128, 16  0          ['activation_109[0][0]']
#  )                              )
#
#  concatenate_48 (Concatenate)   (None, 128, 128, 32  0           ['up_sampling2d_31[0][0]',
#                                 )                                 'activation_100[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 128, 128, 16  4624        ['concatenate_48[0][0]']
#                                 )
#
#  batch_normalization_110 (Batch  (None, 128, 128, 16  64         ['conv2d_110[0][0]']
#  Normalization)                 )
#
#  activation_110 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_110[0][0]']
#                                 )
#
#  up_sampling2d_32 (UpSampling2D  (None, 256, 256, 16  0          ['activation_110[0][0]']
#  )                              )
#
#  concatenate_49 (Concatenate)   (None, 256, 256, 32  0           ['up_sampling2d_32[0][0]',
#                                 )                                 'activation_99[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 256, 256, 64  18496       ['concatenate_49[0][0]']
#                                 )
#
#  batch_normalization_111 (Batch  (None, 256, 256, 64  256        ['conv2d_111[0][0]']
#  Normalization)                 )
#
#  activation_111 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_111[0][0]']
#                                 )
#
#  add_10 (Add)                   (None, 256, 256, 64  0           ['activation_111[0][0]',
#                                 )                                 'activation_98[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 128, 128, 1)  577         ['add_9[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 64, 64, 1)    1153        ['add_8[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 32, 32, 1)    2305        ['add_7[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 16, 16, 1)    4609        ['add_6[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 8, 8, 1)      4609        ['add_5[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 256, 256, 1)  577         ['add_10[0][0]']
#
#  up_sampling2d_33 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_113[0][0]']
#  )
#
#  up_sampling2d_34 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_114[0][0]']
#  )
#
#  up_sampling2d_35 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_115[0][0]']
#  )
#
#  up_sampling2d_36 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_116[0][0]']
#  )
#
#  up_sampling2d_37 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_117[0][0]']
#  )
#
#  concatenate_50 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_112[0][0]',
#                                                                   'up_sampling2d_33[0][0]',
#                                                                   'up_sampling2d_34[0][0]',
#                                                                   'up_sampling2d_35[0][0]',
#                                                                   'up_sampling2d_36[0][0]',
#                                                                   'up_sampling2d_37[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 256, 256, 1)  55          ['concatenate_50[0][0]']
#
#  activation_112 (Activation)    (None, 256, 256, 1)  0           ['conv2d_118[0][0]']
#
#  activation_113 (Activation)    (None, 256, 256, 1)  0           ['conv2d_112[0][0]']
#
#  activation_114 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_33[0][0]']
#
#  activation_115 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_34[0][0]']
#
#  activation_116 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_35[0][0]']
#
#  activation_117 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_36[0][0]']
#
#  activation_118 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_37[0][0]']
#
# ==================================================================================================
# Total params: 44,038,717
# Trainable params: 44,009,917
# Non-trainable params: 28,800
# __________________________________________________________________________________________________

# %%
metrics = [dice_coef, iou, Recall(), Precision()]
model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=Adam(lr), metrics=metrics)

# %% [markdown]
# # Data Preprocessing

# %%
images, masks = load_data(path)
print(f'image: {len(images)} - Masks: {len(masks)}')
# Out:
# image: 722 - Masks: 722

# %%
train_image = images
train_masks = masks
test_image = images[700:]
test_masks = masks[700:]
print(f'image: {len(train_image)} - Masks: {len(train_masks)}')
print(f'image: {len(test_image)} - Masks: {len(test_masks)}')
# Out:
# image: 722 - Masks: 722
# image: 22 - Masks: 22

# %%
n = 200
img = cv2.imread(train_image[n], cv2.IMREAD_COLOR)
msk = cv2.imread(train_masks[n], cv2.IMREAD_COLOR)

fig, ax = plt.subplots(1,2, figsize=(10,8))
ax[0].imshow(img)
ax[1].imshow(msk)

# %%
#convert dataset into tf dataset
train_dataset = tf_dataset(train_image, train_masks, batch=BATCH_SIZE)
test_dataset = tf_dataset(test_image, test_masks, batch=BATCH_SIZE)

# %%
#Callbacks
Callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True), 
    CSVLogger(csv_path),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3
.3200 - val_activation_112_loss: 0.4154 - val_activation_113_loss: 0.1595 - val_activation_114_loss: 0.0329 - val_activation_115_loss: 0.2186 - val_activation_116_loss: 0.0302 - val_activation_117_loss: 0.0805 - val_activation_118_loss: 0.3829 - val_activation_112_dice_coef: 0.5639 - val_activation_112_iou: 0.3928 - val_activation_112_recall: 0.9471 - val_activation_112_precision: 0.7974 - val_activation_113_dice_coef: 0.7592 - val_activation_113_iou: 0.6119 - val_activation_113_recall: 0.9515 - val_activation_113_precision: 0.9860 - val_activation_114_dice_coef: 0.9659 - val_activation_114_iou: 0.9341 - val_activation_114_recall: 0.9665 - val_activation_114_precision: 0.9816 - val_activation_115_dice_coef: 0.6947 - val_activation_115_iou: 0.5323 - val_activation_115_recall: 0.9581 - val_activation_115_precision: 0.9800 - val_activation_116_dice_coef: 0.9646 - val_activation_116_iou: 0.9317 - val_activation_116_recall: 0.9586 - val_activation_116_precision: 0.9837 - val_activation_117_dice_coef: 0.8658 - val_activation_117_iou: 0.7635 - val_activation_117_recall: 0.9601 - val_activation_117_precision: 0.9777 - val_activation_118_dice_coef: 0.5683 - val_activation_118_iou: 0.3970 - val_activation_118_recall: 0.9810 - val_activation_118_precision: 0.8515 - lr: 1.0000e-06

# %% [markdown]
# # Prediction

# %%
path = "/kaggle/working/predicted"
create_dir(path)

# %%
for img, msk in tqdm(zip(test_image, test_masks), total=len(test_image)):
    image_name = img.split("/")[-1]

    ori_x = cv2.imread(img, cv2.IMREAD_COLOR)
    ori_x = cv2.resize(ori_x, (W,H))
    x = ori_x / 255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)

    ori_y = cv2.imread(msk, cv2.IMREAD_GRAYSCALE)
    ori_y = cv2.resize(ori_y, (W,H))
    ori_y = np.expand_dims(ori_y, axis=-1)

    y_pred = model.predict(x)[0] > 0.5  
    y_pred = y_pred.astype(np.int32)
    y_pred = y_pred.reshape(256, 256, 1)

    print(ori_x.shape, ori_y.shape, y_pred.shape)
    save_image_path = f"/kaggle/working/predicted/{image_name}"

    sep_line = np.ones((H, 10, 3)) * 255
    cat_image = np.concatenate([ori_y, y_pred*255], axis=1)
    cv2.imwrite(save_image_path, cat_image)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 1/1 [==============================] - 3s 3s/step
#   5%|▍         | 1/22 [00:03<01:13,  3.48s/it]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 40ms/step
#   9%|▉         | 2/22 [00:03<00:30,  1.51s/it]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 41ms/step
#  14%|█▎        | 3/22 [00:03<00:16,  1.15it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 40ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 39ms/step
#  23%|██▎       | 5/22 [00:03<00:07,  2.33it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 42ms/step
#  27%|██▋       | 6/22 [00:04<00:05,  2.91it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 44ms/step
#  32%|███▏      | 7/22 [00:04<00:04,  3.53it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 45ms/step
#  36%|███▋      | 8/22 [00:04<00:03,  4.33it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 41ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 41ms/step
#  45%|████▌     | 10/22 [00:04<00:02,  5.66it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 41ms/step
#  50%|█████     | 11/22 [00:04<00:01,  5.85it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 38ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 38ms/step
#  59%|█████▉    | 13/22 [00:04<00:01,  7.27it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 39ms/step
#  64%|██████▎   | 14/22 [00:04<00:01,  7.40it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 40ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 41ms/step
#  73%|███████▎  | 16/22 [00:05<00:00,  7.89it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 42ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 43ms/step
#  82%|████████▏ | 18/22 [00:05<00:00,  8.61it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 42ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 40ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
#  91%|█████████ | 20/22 [00:05<00:00,  9.16it/s]
# 1/1 [==============================] - 0s 42ms/step
# (256, 256, 3) (256, 256, 1) (256, 256, 1)
# 1/1 [==============================] - 0s 39ms/step
# 100%|██████████| 22/22 [00:05<00:00,  3.79it/s]
# (256, 256, 3) (256, 256, 1) (256, 256, 1)

# %%
i = "/kaggle/working/predicted/709.png"
i = cv2.imread(i, cv2.IMREAD_GRAYSCALE)
plt.imshow(i)
plt.xlabel("truth                                     predicted")
# Out:
# Text(0.5, 0, 'truth                                     predicted')

# %%
t_path = "/kaggle/working/"
image_folder = sorted(glob(os.path.join(t_path, "predicted/*")))

# %% [markdown]
# # Visualization

# %%
rows = 2
columns = 5

# Create a figure and axis objects
fig, axes = plt.subplots(rows, columns, figsize=(20, 5))

# Flatten the axes array to iterate through it easily
axes = axes.flatten()

# Loop through the images and display them
for i, ax in enumerate(axes):
    # Check if there are more images than needed for the grid
    if i < len(image_folder):
        # Read the image file
        image = mpimg.imread(image_folder[i])
        # Display the image
        ax.imshow(image)
        ax.axis("off")
    else:
        # If there are no more images, hide the remaining axes
        ax.axis("off")

# Adjust the spacing between the subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Skull Stripping

# %%
test_img_path = train_image[609]
test_img_mask = train_masks[609]
test_img = read_img(test_img_path)
test_msk = read_mask(test_img_mask)
plt.imshow(test_img)

# %%
img = test_img.reshape(1, 256, 256, 3)
img.shape
# Out:
# (1, 256, 256, 3)

# %%
pred = model.predict(img)[0] > 0.5  
pred = pred.astype(np.int32)
pred_img = pred.reshape(256, 256, 1)
# Out:
# 1/1 [==============================] - 0s 40ms/step

# %%
fig, ax = plt.subplots(1, 3, figsize=(16,8))
ax[0].imshow(test_img)
ax[0].set_xlabel("BRAIN")
ax[1].imshow(test_msk)
ax[1].set_xlabel("TRUE MASK")
ax[2].imshow(pred_img)
ax[2].set_xlabel("PREDICTED MASK")
# Out:
# Text(0.5, 0, 'PREDICTED MASK')

# %%
#save the predicted mask image
cv2.imwrite("/kaggle/working/mask-1.png", pred_img)
# Out:
# True

# %%
#read mask again
maskImg = cv2.imread("/kaggle/working/mask-1.png")
print(maskImg.shape)
maskImg = cv2.cvtColor(maskImg, cv2.COLOR_BGR2GRAY)
maskImg.shape
# Out:
# (256, 256, 3)
# (256, 256)

# %%
# Bitwise AND the masked brain image with the masked image to remove the skull
masked = cv2.bitwise_and(test_img, test_img, mask=maskImg)

# %%
#visualize
fig, ax = plt.subplots(1, 3, figsize=(15, 12))
ax[0].imshow(test_img)
ax[0].set_xlabel("MRI BRAIN")
ax[1].imshow(maskImg)
ax[1].set_xlabel("BRAIN MASK")
ax[2].imshow(masked)
ax[2].set_xlabel("SKULL STRIPPED BRAIN")
# Out:
# Text(0.5, 0, 'SKULL STRIPPED BRAIN')
